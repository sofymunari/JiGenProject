# %% [markdown]
# <a href="https://colab.research.google.com/github/sofymunari/JiGenProject/blob/main/Run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install requirements**

# %%
# !pip3 install 'torch==1.4.0'
# !pip3 install 'torchvision==0.5.0'
# !pip3 install 'tensorflow-gpu==1.15.0'
# !pip3 install 'scipy==1.5.2'
# Out:
# ...
#      |████████████████████████████████| 753.4MB 24kB/s
# ERROR: torchvision 0.10.0+cu102 has requirement torch==1.9.0, but you'll have torch 1.4.0 which is incompatible.
# ERROR: torchtext 0.10.0 has requirement torch==1.9.0, but you'll have torch 1.4.0 which is incompatible.
# ...
#   Found existing installation: torch 1.9.0+cu102
#     Uninstalling torch-1.9.0+cu102:
#       Successfully uninstalled torch-1.9.0+cu102
# ...
#      |████████████████████████████████| 4.0MB 3.0MB/s
# ...
#   Found existing installation: torchvision 0.10.0+cu102
#     Uninstalling torchvision-0.10.0+cu102:
#       Successfully uninstalled torchvision-0.10.0+cu102
# ...
#      |████████████████████████████████| 411.5MB 41kB/s
# ...
#      |████████████████████████████████| 51kB 70kB/s
# ...
#      |████████████████████████████████| 512kB 45.1MB/s
# ...
#      |████████████████████████████████| 3.8MB 17.0MB/s
# ...

# %% [markdown]
# **Import libraries**

# %%
import os
if not os.path.isdir('./JiGenProject'):
  # !git clone https://github.com/sofymunari/JiGenProject.git
# Out:
# Cloning into 'JiGenProject'...
# remote: Enumerating objects: 10192, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 10192 (delta 71), reused 67 (delta 35), pack-reused 10086
# Receiving objects: 100% (10192/10192), 174.26 MiB | 31.37 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# Checking out files: 100% (10015/10015), done.

# %% [markdown]
# *RUN* DA JIGSAW ONLY

# %%
# !python JiGenProject/train_DA.py --source photo cartoon sketch --target art_painting --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source art_painting cartoon sketch --target photo --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo art_painting sketch --target cartoon --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo cartoon art_painting --target sketch --path_dataset /content/JiGenProject
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 55.2MB/s]
# Dataset size: train 8598, val 950, test 2457
# Step size: 24
# Saving to /content/JiGenProject/utils/../logs/cartoon-photo-sketch_to_art_painting/eps30_bs128_lr0.001_class7_TAll_739
# New epoch - lr: 0.001
# 0/67 of epoch 1/30 Class Loss  : 2.190, Jigsaw Loss : 3.014, Jigsaw Target Loss : 2.975 - Class Accuracy  : 8.59, Jigsaw Accuracy  : 7.81, Jigsaw Accuracy Target : 9.38 [bs:128]

# %% [markdown]
# RUN DG JIGSAW ONLY

# %%
# !python JiGenProject/train_DG.py --source photo cartoon sketch --target art_painting --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source art_painting cartoon sketch --target photo --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source photo art_painting sketch --target cartoon --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source photo cartoon art_painting --target sketch --path_dataset /content/JiGenProject
# Out:
# Using  AlexNet
# Dataset size: train 8579, val 950, test 2457
# Step size: 24
# Saving to /content/JiGenProject/utils/../logs/cartoon-photo-sketch_to_art_painting/eps30_bs128_lr0.001_class7_TAll_600
# New epoch - lr: 0.001
# 0/67 of epoch 1/30 Class Loss  : 1.934, Jigsaw Loss : 3.513 - Class Accuracy  : 14.84, Jigsaw Accuracy  : 2.34 [bs:128]
# 30/67 of epoch 1/30 Class Loss  : 0.682, Jigsaw Loss : 0.653 - Class Accuracy  : 62.50, Jigsaw Accuracy  : 82.81 [bs:128]
# 60/67 of epoch 1/30 Class Loss  : 0.433, Jigsaw Loss : 0.746 - Class Accuracy  : 73.44, Jigsaw Accuracy  : 81.25 [bs:128]
# Accuracies on val: Classification Accuracy : 74.63, Jigsaw Accuracy : 83.89
# Accuracies on test: Classification Accuracy : 54.46, Jigsaw Accuracy : 83.56
# New epoch - lr: 0.001
# 0/67 of epoch 2/30 Class Loss  : 0.437, Jigsaw Loss : 0.670 - Class Accuracy  : 74.22, Jigsaw Accuracy  : 82.81 [bs:128]
# ...

# %% [markdown]
# RUN DA JIGSAW AND ROTATION

# %%
# !python JiGenProject/train_DA.py --source photo cartoon sketch --target art_painting --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source art_painting cartoon sketch --target photo --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo art_painting sketch --target cartoon --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo cartoon art_painting --target sketch --rotation True --path_dataset /content/JiGenProject
# Out:
# Dataset size: train 10030, val 1107, test 2866
# Step size: 24
# Saving to /content/JiGenProject/utils/../logs/cartoon-photo-sketch_to_art_painting/eps30_bs128_lr0.001_class7_TAll_201
# New epoch - lr: 0.001
# 0/78 of epoch 1/30 Class Loss  : 2.168, Jigsaw Loss : 3.508, Jigsaw Target Loss : 3.500, Rotation Loss : 1.266, Rotation Loss Target : 1.210 - Class Accuracy  : 13.28, Jigsaw Accuracy  : 0.78, Jigsaw Accuracy Target : 0.78, Rotation Accuracy  : 38.28, Rotation Accuracy Target : 40.62 [bs:128]
# 30/78 of epoch 1/30 Class Loss  : 1.285, Jigsaw Loss : 0.643, Jigsaw Target Loss : 0.605, Rotation Loss : 0.537, Rotation Loss Target : 0.651 - Class Accuracy  : 50.00, Jigsaw Accuracy  : 75.78, Jigsaw Accuracy Target : 73.44, Rotation Accuracy  : 75.78, Rotation Accuracy Target : 73.44 [bs:128]
# ...

# %% [markdown]
# RUN DG JIGSAW AND ROTATION

# %%
# !python JiGenProject/train_DG.py --source photo cartoon sketch --target art_painting --rotation True --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source art_painting cartoon sketch --target photo --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source photo art_painting sketch --target cartoon --rotation True --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source photo cartoon art_painting --target sketch --rotation True --path_dataset /content/JiGenProject

# %% [markdown]
# RUN DA JIGSAW AND ODD ONE OUT

# %%
# !python JiGenProject/train_DA.py --source photo cartoon sketch --target art_painting --oddOneOut True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source art_painting cartoon sketch --target photo --oddOneOut True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo art_painting sketch --target cartoon --oddOneOut True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo cartoon art_painting --target sketch --oddOneOut True --path_dataset /content/JiGenProject
# Out:
# Dataset size: train 8601, val 953, test 2458
# Step size: 24
# Saving to /content/JiGenProject/utils/../logs/cartoon-photo-sketch_to_art_painting/eps30_bs128_lr0.001_class7_TAll_756
# New epoch - lr: 0.001
# /pytorch/aten/src/THCUNN/ClassNLLCriterion.cu:106: void cunn_ClassNLLCriterion_updateOutput_kernel(Dtype *, Dtype *, Dtype *, long *, Dtype *, int, int, int, int, long) [with Dtype = float, Acctype = float]: block: [0,0,0], thread: [16,0,0] Assertion `t >= 0 && t < n_classes` failed.
# /pytorch/aten/src/THCUNN/ClassNLLCriterion.cu:106: void cunn_ClassNLLCriterion_updateOutput_kernel(Dtype *, Dtype *, Dtype *, long *, Dtype *, int, int, int, int, long) [with Dtype = float, Acctype = float]: block: [0,0,0], thread: [18,0,0] Assertion `t >= 0 && t < n_classes` failed.
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCCachingHostAllocator.cpp line=278 error=710 : device-side assert triggered
# Traceback (most recent call last):
# ...

# %% [markdown]
# RUN DG JIGSAW AND ODD ONE OUT

# %%
# !python JiGenProject/train_DG.py --source photo cartoon sketch --target art_painting --oddOneOut True --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source art_painting cartoon sketch --target photo --oddOneOut True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source photo art_painting sketch --target cartoon --oddOneOut True --path_dataset /content/JiGenProject  
# !python JiGenProject/train_DG.py --source photo cartoon art_painting --target sketch --oddOneOut True --path_dataset /content/JiGenProject

# %% [markdown]
# RUN DA JIGSAW AND ODD ONE OUT AND ROTATION

# %%
# !python JiGenProject/train_DA.py --source photo cartoon sketch --target art_painting --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source art_painting cartoon sketch --target photo --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo art_painting sketch --target cartoon --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DA.py --source photo cartoon art_painting --target sketch --oddOneOut True --rotation True --path_dataset /content/JiGenProject

# %% [markdown]
# RUN DG JIGSAW AND ODD ONE OUT AND ROTATION

# %%
# !python JiGenProject/train_DG.py --source photo cartoon sketch --target art_painting --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source art_painting cartoon sketch --target photo --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source photo art_painting sketch --target cartoon --oddOneOut True --rotation True --path_dataset /content/JiGenProject 
# !python JiGenProject/train_DG.py --source photo cartoon art_painting --target sketch --oddOneOut True --rotation True --path_dataset /content/JiGenProject
